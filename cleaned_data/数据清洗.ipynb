# %% [markdown]
# # 2. 数据预处理（清洗+集成{规约+变换}+可视化？）
#
# 1. 统一使用三个字母国家代码
#    1. 首先确定使用三个字母NOC而不使用Team的充分理由，即大部分NOC对应一个Team,统计结果如下图所示；并且在统计金牌时是以国家为单位，team并无太大意义，故可以删除Team这一列

# %%
from data_clean import*
delete_team("summerOly_athletes.csv")
# Out:
#    NOC  Unique Team Count
# 0  AFG                  1
# 1  AHO                  1
# 2  AIN                  1
# 3  ALB                  1
# 4  ALG                  1
# 5  AND                  1
# 6  ANG                  1
# 7  ANT                  1
# 8  ANZ                  2
# 9  ARG                 18

# %% [markdown]
# 2. 缺失值/特殊符号处理
#     1.
# 3. 算历史奖牌数
#
# 4. 创建主办国变量
#
# 5. 整合运动员数据倒每一届里面
# 6. 可视化
